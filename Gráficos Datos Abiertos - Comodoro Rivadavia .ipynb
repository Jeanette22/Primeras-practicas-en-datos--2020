# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Gráfico de Patentamiento Automotor- 2020 Comodoro Rivadavia

# %%
dataset = pd.read_csv ("patentamiento-automotor-2020.csv")

# %%
dataset.head (10)
# Out:
#     TIPO AUTOMOTOR  CANTIDAD
# 0        Automóvil    75.361
# 1          Pick Up    24.981
# 2           Furgón     3.957
# 3            Rural     7.148
# 4           Camión     5.068
# 5  Casilla Rodante   266.000
# 6   Camión Tractor   894.000
# 7          Ómnibus     1.852
# 8      Cuatriciclo   371.000
# 9         Acoplado   569.000

# %%
gen_cnt = grafico2['CANTIDAD'].value_counts()

# %%
info =[('Ómnibus', 1852),('Furgón', 3957), ('Camión', 5068),('Rural',7148), ('Pickup', 24981), ('Automovil', 75361), ('Casilla Rodante', 266000), ('Cuatriciclo', 371000),('Aclopado', 569000), ('Camion Tractor', 894000)]

data = []
for v, c in info:
  data.extend([v]*c)


grafico2 = pd.DataFrame(data, columns=["CANTIDAD"])

ordered = sorted(gen_cnt.items(), key=lambda x: x[1], reverse=True)
order = [ valor for valor, contador in ordered ]
gen_cnt = grafico2['CANTIDAD'].value_counts()


plt.figure (figsize=(10,8))

plt.title ('Patentamiento Automotor 2020- Com. Riv.')
sns.countplot(data=grafico2, y='CANTIDAD', color="lime", order=order)
grafico2 = gen_cnt.values.sum()
for i, (valor, contador) in enumerate(ordered):
   pcnt = '{:0.1f}%'.format(100*contador/grafico2)
   plt.text(contador-100, i, pcnt, va ='center')
plt.text(30,0," 894.000",fontsize= 9,  color= "black")
# Out:
# Text(30, 0, ' 894.000')

# %%
import folium

# %%
-45.8661712,-67.4870946
# Out:
# (-45.8661712, -67.4870946)

# %%
padron = pd.read_csv ("https://datos.vivamoscomodoro.gob.ar/base/datasets/scuyo/dit/establecimientos-educativos.csv") 
padron.head(20)
# Out:
#      cueanexo      cue  Anexo Nro.                                  Nombre  \
# 0   260039800  2600398      0    1                     Patagonia Argentina
# 1   260000600  2600006      0    2                   Francisco Pietrobelli
# 2   260003500  2600035      0   13   Libertador General José De San Martín
# 3   260031500  2600315      0   23                    Dr. Carlos Madariaga
# 4   260000700  2600007      0   26                      Ejército Argentino
# 5   260037000  2600370      0   27                       Fray Luis Beltran
# 6   260006300  2600063      0   32                     Repùblica Argentina
# 7   260012700  2600127      0   34            Ciudad De Comodoro Rivadavia
# 8   260039200  2600392      0   39              Sgto. Juan Bautista Cabral
# 9   260037600  2600376      0   43           Ingeniero Luis Augusto Huergo
# 10  260020600  2600206      0   44               Coronel Félix De Olazábal
# 11  260004500  2600045      0   52                  Ciudad De Buenos Aires
# 12  260038500  2600385      0   83                Tte. Gral. Julio A. Roca
# 13  260037500  2600375      0   91  Gabina Del Carmen Suarez De Magallanes
# 14  260020700  2600207      0  104                    Francisco José Seguí
# 15  260003400  2600034      0  105                        Bandera Nacional
# 16  260040600  2600406      0  111                           Mar Argentino
# 17  260021100  2600211      0  115                         13 De Diciembre
# 18  260028600  2600286      0  119                      Nicolas Avellaneda
# 19  260027200  2600272      0  126                    A.R.A. Punta Medanos
#
#      sector dependencia          telefono    nro_red  \
# 0   Estatal  Provincial           4464038       2038
# 1   Estatal  Provincial           4465172       2172
# 2   Estatal  Provincial           4462561       2561
# 3   Estatal  Provincial           4548229       2230
# 4   Estatal  Provincial           4462534  2534/2796
# 5   Estatal  Provincial           4560069       2069
# 6   Estatal  Provincial  4483860/ 4486788       2860
# 7   Estatal  Provincial           4462116       2116
# 8   Estatal  Provincial           4461054       2054
# 9   Estatal  Provincial           4550690       2690
# 10  Estatal  Provincial           4548865       2866
# 11  Estatal  Provincial           4462627       2627
# 12  Estatal  Provincial           4464798       2798
# 13  Estatal  Provincial           4557018       2018
# 14  Estatal  Provincial           4590142       2142
# 15  Estatal  Provincial           4474067       2067
# 16  Estatal  Provincial           4558014       2014
# 17  Estatal  Provincial           4843098        NaN
# 18  Estatal  Provincial           4462514       2513
# 19  Estatal  Provincial           4535655        NaN
#
#                                              E-mail sitio_web  \
# 0                   ep1patagoniaargentina@gmail.com       NaN
# 1                          direscuela2@yahoo.com.ar       NaN
# 2                        escuela13.chubut@gmail.com       NaN
# 3                          escuela23@hotmail.com.ar       NaN
# 4                  escuela26institucional@gmail.com       NaN
# 5            escuela27_frayluisbeltran@yahoo.com.ar       NaN
# 6                         escuela32chubut@gmail.com       NaN
# 7                       escuela34comodoro@gmail.com       NaN
# 8   escuelaprov39@live.com.ar/escuela39cr@gmail.com       NaN
# 9                       ingenieroluis43@hotmail.com       NaN
# 10                       escuela44km11.cr@gmail.com       NaN
# 11                              escprov52@gmail.com       NaN
# 12                   comodoro_escuela83@hotmail.com       NaN
# 13                        esc91_vallec@yahoo.com.ar       NaN
# 14                        escuelan104cc@hotmail.com       NaN
# 15                   escuela105comodoro@hotmail.com       NaN
# 16                  direccionmarargentino@gmail.com       NaN
# 17   escuela_115@yahoo.com.ar/e115.chubut@gmail.com       NaN
# 18          escuela119nicolasavellaneda@hotmail.com       NaN
# 19                          escuela126@yahoo.com.ar       NaN
#
#                         calle     nro_calle
# 0           Hipólito Irigoyen           748
# 1                      Huergo          1545
# 2                     Artigas           650
# 3              Juan José Paso          1449
# 4             Avda. Rivadavia          2190
# 5                      Bogotá           845
# 6                      Canadá           S/N
# 7                  Granaderos  y 1° de Mayo
# 8                  Santa Cruz           370
# 9          Pampa Del Castillo           250
# 10    Fortín Chacabuco- Km.11           NaN
# 11                Av. Kennedy          1800
# 12                  Rivadavia           751
# 13                 Entre Ríos          3060
# 14              Punta Novales           450
# 15                    Jornada          2326
# 16  Margarita Galetto De Abad           351
# 17             Lago Argentino           445
# 18                 San Martín          1451
# 19       Avda. Alejandro Maíz           NaN

# %%
coordenadas =  ['padron']+ 2499242
padron = padron.assign (coordenas = coordenas.values)
print (padron)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-e293e961bb97> in <module>
# ----> 1 coordenadas =  ['padron']+ 2499242
#       2 padron = padron.assign (coordenas = coordenas.values)
#       3 print (padron)
#
# TypeError: can only concatenate list (not "int") to list

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\jeanette22\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: numpy in c:\users\jeanette22\anaconda3\lib\site-packages (from folium) (1.20.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\jeanette22\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in c:\users\jeanette22\anaconda3\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in c:\users\jeanette22\anaconda3\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jeanette22\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jeanette22\anaconda3\lib\site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\jeanette22\anaconda3\lib\site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jeanette22\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeanette22\anaconda3\lib\site-packages (from requests->folium) (2020.12.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
mapa = folium.Map(location=[-45.86413, -67.49656], zoom_start=10)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_82f111f9bd884a78891b3d7d4adfe6dd%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_82f111f9bd884a78891b3d7d4adfe6dd%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_82f111f9bd884a78891b3d7d4adfe6dd%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_82f111f9bd884a78891b3d7d4adfe6dd%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-45.86413%2C%20-67.49656%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
def coord(c):
    coor = re.findall(r'-?\d+\.\d{7}', c)
    coords = [float(s) for s in coor]
    return coords[::-1]

# %% [markdown]
# # ACCIDENTES DE TRANSITOS 2020- COMODORO RIVADAVIA

# %%
accidentes = pd.read_csv ("https://datos.vivamoscomodoro.gob.ar/base/datasets/scuyo/dit/tipo-accidente-transito-serie.csv")

# %%
accidentes.head()
# Out:
#            Tipo de accidente de tránsito  Año 2018  Año 2019  Año 2020
# 0                Siniestros sin víctimas     1.176     1.399       941
# 1  Siniestros con heridos leves y graves   115.000   118.000        52
# 2        Siniestros con víctimas fatales    12.000     5.000         5
# 3                                  Total     1.303     1.522       998

# %%
labels = ['Año 2018', 'Año 2019', 'Año 2020']

# %%
dato1 = [3.516,233.052,17.005] #total cada uno
etiquetas = ["siniestros sin victimas", "Siniestros con heridos leves y graves", "Siniestros con víctimas fatales"]



fig = plt.figure(figsize=(10, 7))
explode = [0, 0, 0.8]
colores = ['limegreen','darkorange','gold']
plt.pie(dato1, labels = etiquetas, colors = colores, explode=explode,
        autopct='%1.2f%%', shadow=True, startangle=15)
plt.title('ACCIDENTES VIALES - 2018 al 2020 - CRD')


plt.show()
